# %% [markdown]
# Problem 1
# ---------
#
# a)
#
# $$ s = v_bt $$
# $$ s = d\sqrt{2} $$
#
# b)
#
# $$ t = \frac{s}{v_b} $$
# $$ t = \frac{d\sqrt{2}}{v_b} $$
#
# c)
#
# $$ dv = a dt = a_{p0}(1-\frac{t}{\tau}) dt$$
# $$ v_p = a_{p0}(t - \frac{t^2}{2\tau}) $$
# $$ v_p = a_{p0}(\frac{d\sqrt{2}}{v_b} - \frac{d^2}{v_b^2\tau}) $$
#
#
# d)
# $$ ds = v_p dt $$
# $$ s(t) = a_{p0}\frac{t^2}{2}(1 - \frac{t}{3 \tau}) $$
#
# e)
# substitue b in to d
#
# $$ -d = a_{p0}\frac{d^2}{v_b^2}(1 - \frac{d\sqrt{2}}{3v_b\tau}) $$
#
# $$ a_{p0} = \frac{-3v_b^3\tau}{d(v_b3\tau - d\sqrt{2})} $$
#
# f) use e in c
#
# $$ v_p = \frac{-3v_b^2\tau}{(v_b3\tau - d\sqrt{2})}(\sqrt{2} - \frac{d}{v_b\tau}) $$

# %% [markdown]
# Problem 2
# ---------
#
# <img src='img/exam.png'>
#
# b)
#
# $$ m_1a_1 = T-m_1gsin\alpha $$
# $$ m_2a_2 = -2T+m_2g $$
# $$ m_3a_3 = T_2 $$
#
# c)
#
# $$ J\ddot{\phi} = R(T-T2)$$
# $$ \frac{MR}{2}\ddot{\phi} = T-T2$$
#
# d)
#
# $$ a_3 = \ddot{\phi}R $$
#
# e)
#
# $$ 2a_2 = a_1 + a_3 $$
#
# f)
#
# $$ ma_1 = T-mgsin\alpha $$
# $$ ma_2 = -T+mg $$
# $$ ma_3 = T_2 $$
#
# $$ mR\ddot{\phi} = T-T2$$
# $$ ma_3 = T-ma_3$$
# $$ T = 2ma_3$$
#
# $$ a_1 = 2a_3 - gsin \alpha $$
#
# $$ a_2 = -2a_3 +g = \frac{a_1+a_3}{2}$$
#
# $$ a_1 = -5a_3 +2g = \frac{t}{m} - gsin\alpha $$
#
# $$ a_3 = \frac{g(2-sin\alpha)}{7} $$
#
# $$ a_2 = \frac{-2g(2-sin\alpha)}{7} +g $$
#
# $$ a_1 = \frac{-5g(2 - sin\alpha)}{7} +2g $$

# %% [markdown]
# Problem 3
# ---------
#
# a)
#
# $$ M = m_s + m_b + m_p $$
# $$ m = m_b +m_p $$
#
# $$ \sum F = Ma $$
# $$ F_L - Mg = Ma $$
# $$ F_L = M(a+g) $$
#
# The balloon isn't accelerating initally
#
# $$ F_L = Mg $$
#
# b)
#
# $$ F_L - mg = ma $$
#
# $$ a = \frac{F_L}{m} - g $$
#
# $$ a = \frac{Mg}{m} - g $$
#
#
# $$ a = g(\frac{M}{m}- 1) $$
#
# c)
#
# $$ y_f = y_0 + v_0t + 0.5at^2 $$
#
#
# $$ 0 = h - 0.5gt^2 $$
#
# $$ t = \sqrt{\frac{2h}{g}} $$
#
# d)
#
# $$ y_f = y_0 + v_0t + 0.5at^2 $$
#
# $$ y_f(t) = h + 0.5g(\frac{M}{m}- 1)t^2 $$
